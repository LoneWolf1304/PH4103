# %%
using Plots, CSV, DataFrames, LaTeXStrings

# %%
A = CSV.read("intercept.csv", DataFrame)
B = CSV.read("loop_width.csv", DataFrame)
C = CSV.read("tip-tip.csv", DataFrame)
# Out:
# 8×2 DataFrame
#  Row │ B      tip
#      │ Int64  Float64
# ─────┼────────────────
#    1 │    61      3.6
#    2 │    95      4.2
#    3 │   134      4.6
#    4 │   173      4.6
#    5 │   223      4.8
#    6 │   265      4.8
#    7 │   307      4.8
#    8 │   342      4.8

# %%
scatter(C[!,1], C[!,2])
scatter!(A[!,1], A[!,2], ylim=(2,6))
scatter(B[!,1], B[!,2], ylim=(0,5))

# %%
import numpy as np

# %%
G0 = 3.04
alpha = 0.13975
N = 0.013776
gx = 100
gy = 1
mu = 1
# Out:
# 1

# %%
ex = [1.8, 2, 2.4, 2.8, 3.2, 3.4, 3.6, 3.8]
coer = [G0 * i/2 /(alpha - N) for i in ex]
coer
# Out:
# 8-element Vector{Float64}:
#  21.718767364694305
#  24.131963738549224
#  28.958356486259067
#  33.78474923396891
#  38.61114198167876
#  41.02433835553368
#  43.43753472938861
#  45.850731103243525

# %%
ey = [3.6, 4.2, 4.6, 4.6, 4.8, 4.8, 4.8, 4.8]
sat = [G0 * mu * gx * i /2 / gy / (alpha - N) / (4* pi) for i in ey]
sat
# Out:
# 8-element Vector{Float64}:
#  345.66491839540356
#  403.2757381279708
#  441.6829512830156
#  441.6829512830156
#  460.886557860538
#  460.886557860538
#  460.886557860538
#  460.886557860538

# %%
ey = []
ret = []
# Out:
# Any[]
